# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"D:\AI-and-Machine_Learning_Diploma\Deep_Learning\Session_5\Image\WhatsApp Image 2026-07-08 at 9.58.29 PM.jpeg")

# %%
cv2.imshow("Image", img)

# %%
import cv2
import matplotlib.pyplot as plt

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(img)
# Out:
# [[[241 255 253]
#   [241 255 253]
#   [242 255 253]
#   ...
#   [242 254 254]
#   [225 233 233]
#   [  3  11  11]]
#
#  [[241 255 253]
#   [241 255 253]
#   [242 255 253]
#   ...
#   [242 254 254]
#   [225 233 233]
#   [  3  11  11]]
#
#  [[241 255 253]
#   [241 255 253]
#   [242 255 253]
#   ...
#   [242 254 254]
#   [225 233 233]
#   [  3  11  11]]
#
#  ...
#
#  [[ 10   7  29]
#   [ 10   7  29]
#   [ 11   9  29]
#   ...
#   [152 151 147]
#   [145 144 140]
#   [  9   8   4]]
#
#  [[ 10   7  29]
#   [ 10   7  29]
#   [ 11   9  29]
#   ...
#   [152 151 147]
#   [145 144 140]
#   [  9   8   4]]
#
#  [[ 10   7  29]
#   [ 10   7  29]
#   [ 11   9  29]
#   ...
#   [152 151 147]
#   [145 144 140]
#   [  9   8   4]]]
