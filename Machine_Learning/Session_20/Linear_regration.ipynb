# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Sample data: predicting house price based on size
data = {'Size': [500, 750, 1000, 1250, 1500],
        'Price': [150000, 200000, 250000, 300000, 350000]}

# %%
df = pd.DataFrame(data)

# %%
# Define the feature (independent variable) and target (dependent variable)
X = df[['Size']]
y = df['Price']

# %%
# Create and train the model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)

# %%
# Plot the results
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, predictions, color='red', label='Linear Regression Line')
plt.xlabel('Size (sq ft)')
plt.ylabel('Price ($)')
plt.title('Simple Linear Regression: House Price Prediction')
plt.legend()
plt.show()

# %%
# Sample data: predicting house price based on size, bedrooms, and age
data = {'Size': [500, 750, 1000, 1250, 1500],
        'Bedrooms': [1, 2, 3, 3, 4],
        'Age': [5, 10, 15, 20, 25],
        'Price': [150000, 200000, 250000, 300000, 350000]}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#    Size  Bedrooms  Age   Price
# 0   500         1    5  150000
# 1   750         2   10  200000
# 2  1000         3   15  250000
# 3  1250         3   20  300000
# 4  1500         4   25  350000

# %%
# Deffine the feature (independent variables ) and target (dependant variable )

# %%
data = {'Time' : [1,2,3,4,5],'progression':[1,4,9,16,25]}

# %%
df3 = pd.DataFrame(data)

# %%
X = df3[['Time']]
y = df3[['progression']]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
lr = LinearRegression()

# %%
lr .fit(X,y)
# Out:
# LinearRegression()

# %%
df = pd.read_csv(r'D:\AI-and-Machine_Learning_Diploma\Machine_Learning\Session_20\retail_analytics_20k.csv.xls')

# %%
df
# Out:
#          order_id  order_date  year  month month_name quarter customer_id  \
# 0      ORD-000001  2025-10-16  2025     10    October      Q4  CUST-02941
# 1      ORD-000002  2025-09-10  2025      9  September      Q3  CUST-01402
# 2      ORD-000003  2024-09-07  2024      9  September      Q3  CUST-03272
# 3      ORD-000004  2024-08-12  2024      8     August      Q3  CUST-02158
# 4      ORD-000005  2024-07-01  2024      7       July      Q3  CUST-04418
# ...           ...         ...   ...    ...        ...     ...         ...
# 19995  ORD-019996  2025-09-09  2025      9  September      Q3  CUST-02548
# 19996  ORD-019997  2025-06-26  2025      6       June      Q2  CUST-00626
# 19997  ORD-019998  2025-01-11  2025      1    January      Q1  CUST-03102
# 19998  ORD-019999  2025-06-15  2025      6       June      Q2  CUST-03543
# 19999  ORD-020000  2024-06-17  2024      6       June      Q2  CUST-03783
#
#          customer_segment age_group  gender  ... unit_price_egp discount_pct  \
# ...

# %%
df['customer_segment'].unique()
# Out:
# array(['Student', 'Young Professional', 'Premium', 'Family', 'Corporate'],
#       dtype=object)

# %%
df['quarter'].unique()
# Out:
# array(['Q4', 'Q3', 'Q2', 'Q1'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder= LabelEncoder()
df['quarter_encoder'] = label_encoder.fit_transform(df['quarter'])
df
# Out:
#          order_id  order_date  year  month month_name quarter customer_id  \
# 0      ORD-000001  2025-10-16  2025     10    October      Q4  CUST-02941
# 1      ORD-000002  2025-09-10  2025      9  September      Q3  CUST-01402
# 2      ORD-000003  2024-09-07  2024      9  September      Q3  CUST-03272
# 3      ORD-000004  2024-08-12  2024      8     August      Q3  CUST-02158
# 4      ORD-000005  2024-07-01  2024      7       July      Q3  CUST-04418
# ...           ...         ...   ...    ...        ...     ...         ...
# 19995  ORD-019996  2025-09-09  2025      9  September      Q3  CUST-02548
# 19996  ORD-019997  2025-06-26  2025      6       June      Q2  CUST-00626
# 19997  ORD-019998  2025-01-11  2025      1    January      Q1  CUST-03102
# 19998  ORD-019999  2025-06-15  2025      6       June      Q2  CUST-03543
# 19999  ORD-020000  2024-06-17  2024      6       June      Q2  CUST-03783
#
#          customer_segment age_group  gender  ... discount_pct revenue_egp  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot_encoder = OneHotEncoder(sparse_output= False)
encoded_segment = one_hot_encoder.fit_transform(df[['customer_segment']])

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
df = pd.read_csv(r'D:\AI-and-Machine_Learning_Diploma\Machine_Learning\Session_20\retail_analytics_20k.csv.xls')

scaler = StandardScaler()
df[['profit_egp', 'profit_margin']] = scaler.fit_transform(
    df[['profit_egp', 'profit_margin']]
)

# %%
df
# Out:
#          order_id  order_date  year  month month_name quarter customer_id  \
# 0      ORD-000001  2025-10-16  2025     10    October      Q4  CUST-02941
# 1      ORD-000002  2025-09-10  2025      9  September      Q3  CUST-01402
# 2      ORD-000003  2024-09-07  2024      9  September      Q3  CUST-03272
# 3      ORD-000004  2024-08-12  2024      8     August      Q3  CUST-02158
# 4      ORD-000005  2024-07-01  2024      7       July      Q3  CUST-04418
# ...           ...         ...   ...    ...        ...     ...         ...
# 19995  ORD-019996  2025-09-09  2025      9  September      Q3  CUST-02548
# 19996  ORD-019997  2025-06-26  2025      6       June      Q2  CUST-00626
# 19997  ORD-019998  2025-01-11  2025      1    January      Q1  CUST-03102
# 19998  ORD-019999  2025-06-15  2025      6       June      Q2  CUST-03543
# 19999  ORD-020000  2024-06-17  2024      6       June      Q2  CUST-03783
#
#          customer_segment age_group  gender  ... unit_price_egp discount_pct  \
# ...

# %%
minmax_scaler = MinMaxScaler()
df[['revenue_egp']] = minmax_scaler.fit_transform(df[['revenue_egp']])

# %%
df.describe()
# Out:
#                year         month     quantity  unit_price_egp  discount_pct  \
# count  20000.000000  20000.000000  20000.00000    20000.000000  20000.000000
# mean    2024.502600      6.543900      1.83445     6949.031827      0.067510
# std        0.500006      3.433914      1.13838    11266.315666      0.054409
# min     2024.000000      1.000000      1.00000       42.770000      0.000000
# 25%     2024.000000      4.000000      1.00000     1099.825000      0.023300
# 50%     2025.000000      7.000000      1.00000     2868.175000      0.058000
# 75%     2025.000000     10.000000      2.00000     6844.855000      0.101900
# max     2025.000000     12.000000      6.00000    98053.220000      0.287500
#
#         revenue_egp       cost_egp    profit_egp  profit_margin  \
# count  20000.000000   20000.000000  2.000000e+04   2.000000e+04
# mean       0.035881    6652.357934 -2.096101e-17   1.652012e-17
# std        0.060843   12546.068889  1.000025e+00   1.000025e+00
# ...
