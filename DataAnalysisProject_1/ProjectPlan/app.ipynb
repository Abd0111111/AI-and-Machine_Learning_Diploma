# %%
import pymongo
from pymongo import MongoClient
from bson.objectid import ObjectId

# %%
# في كزا package بستخدمها علشان ابني ال API
from flask import Flask , request ,jsonify
import threading
import time

# %%
app = Flask(__name__)
# Create a Flask application instance
# This object represents your API server
# It handles requests and responses

client = MongoClient("mongodb://localhost:27017/")
# Create a connection to MongoDB
# localhost means the database is running on the same machine
# 27017 is the default MongoDB port

db = client['Retail_Business']
# Select the database named Retail_Business
# If it does not exist MongoDB will create it automatically

customers_col = db['customers_warehouse']
# Select the collection named customers
# A collection is similar to a table in SQL
# This is where customer data will be stored

# %%
@app.route("/health")
def health():
    return jsonify({"status": "ok"})

@app.route('/customers_warehouse', methods=['GET'])

def get_customers_warehouse():
    # Define a function that runs when the endpoint is called

    customers_warehouse = []
    # Create an empty list
    # This list will hold all customer records

    for doc in customers_col.find():
        # Loop through all documents in the customers collection
        # find() returns all records from MongoDB

        doc['_id'] = str(doc['_id'])
        # Convert MongoDB ObjectId to string
        # ObjectId cannot be returned as JSON directly

        customers_warehouse.append(doc)
        # Add the modified document to the customers list
        # This prepares the data for the response

    return jsonify(customers_warehouse)
    # Convert the list to JSON format
    # Send the JSON response back to the client

# %%
def run_flask():
    app.run(port=5000, debug=False, use_reloader=False)

threading.Thread(target=run_flask).start()
time.sleep(1)
# http://127.0.0.1:5000/customers_warehouse
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Jan/2026 23:18:55] "GET /customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:03] "GET /customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:05] "GET /customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:06] "GET /customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:11] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:13] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:32] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:19:34] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:22:21] "GET /customers_warehouse HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:22:24] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:29:42] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:35:06] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:35:09] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:36:10] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:36:38] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:36:39] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:36:39] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:36:57] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:38:28] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:39:55] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:39:56] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:42:58] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:16] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:18] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:19] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:19] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:20] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:43:20] "GET /top_customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:42] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:43] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:44] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:44] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:45] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:45] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:45] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:46:45] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:47:01] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:47:04] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:47:35] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:47:48] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:20] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:21] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:22] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:31] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:51:37] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:51] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:51:52] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:52:02] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:52:14] "GET /hleath HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:52:34] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:52:45] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:53:41] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:53:42] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:53:45] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:53:46] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:55:04] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:55:10] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:55:11] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:55:22] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:57:34] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Jan/2026 23:57:38] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:57:38] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:57:39] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jan/2026 23:57:40] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jan/2026 00:00:08] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jan/2026 00:01:05] "GET /health HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jan/2026 00:01:15] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Jan/2026 00:01:16] "GET /top-customers HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Jan/2026 00:01:18] "GET /top-customers HTTP/1.1" 404 -
