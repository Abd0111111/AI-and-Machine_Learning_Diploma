# %%
'''02_data_preprocessing.ipynb

ده يشيل تجهيز الداتا.

يحط فيه:

imports
numpy
pandas

قراءة الداتا من dataset

تنظيف الداتا
القيم الناقصة
تحويل الأعمدة لنوع رقمي

اختيار الـ features
features_to_explore

تعريف X و y

حفظ الداتا النظيفة
to_csv

ممنوع هنا:

أي رسم

أي موديل

الهدف
تطلع داتا جاهزة للتدريب.
'''
# Out:
# '02_data_preprocessing.ipynb\n\nده يشيل تجهيز الداتا.\n\nيحط فيه:\n\nimports\nnumpy\npandas\n\nقراءة الداتا من dataset\n\nتنظيف الداتا\nالقيم الناقصة\nتحويل الأعمدة لنوع رقمي\n\nاختيار الـ features\nfeatures_to_explore\n\nتعريف X و y\n\nحفظ الداتا النظيفة\nto_csv\n\nممنوع هنا:\n\nأي رسم\n\nأي موديل\n\nالهدف\nتطلع داتا جاهزة للتدريب.\n'
