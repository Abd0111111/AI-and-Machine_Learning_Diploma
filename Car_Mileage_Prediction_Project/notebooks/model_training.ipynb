# %%
'''
04_evaluation_analysis.ipynb

ده يشيل التقييم والتحليل.

يحط فيه:

imports
pandas
matplotlib
metrics

قراءة:
y_test
y_pred

حساب:
R²
MSE

طباعة Actual vs Predicted

رسم Actual vs Predicted

تحليل Coefficients
model.coef_

استنتاجات نصية

ممنوع هنا:

تدريب موديل

تنظيف داتا

الهدف
تشرح النتيجة.
'''
