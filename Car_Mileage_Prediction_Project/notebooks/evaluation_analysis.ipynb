# %%
'''03_model_training.ipynb

ده يشيل التدريب فقط.

يحط فيه:

imports
pandas
train_test_split
LinearRegression

قراءة الداتا النظيفة

تقسيم Train و Test

تدريب الموديل
model.fit

التوقع
y_pred

حفظ التوقعات
CSV

ممنوع هنا:

رسم

تحليل

الهدف
تطلع موديل شغال.'''
# Out:
# '03_model_training.ipynb\n\nده يشيل التدريب فقط.\n\nيحط فيه:\n\nimports\npandas\ntrain_test_split\nLinearRegression\n\nقراءة الداتا النظيفة\n\nتقسيم Train و Test\n\nتدريب الموديل\nmodel.fit\n\nالتوقع\ny_pred\n\nحفظ التوقعات\nCSV\n\nممنوع هنا:\n\nرسم\n\nتحليل\n\nالهدف\nتطلع موديل شغال.'
