# %%
"""يحط فيه:

imports
numpy
pandas
matplotlib
seaborn

قراءة الداتا
pd.read_csv

عرض الداتا
head
info
describe

كل الـ scatter plots
زي:

feature vs target

longitude latitude لو موجود

Correlation matrix
heatmap

ممنوع هنا:

train_test_split

LinearRegression

أي تدريب موديل

الهدف
تفهم الداتا بس.
"""
# Out:
# 'يحط فيه:\n\nimports\nnumpy\npandas\nmatplotlib\nseaborn\n\nقراءة الداتا\npd.read_csv\n\nعرض الداتا\nhead\ninfo\ndescribe\n\nكل الـ scatter plots\nزي:\n\nfeature vs target\n\nlongitude latitude لو موجود\n\nCorrelation matrix\nheatmap\n\nممنوع هنا:\n\ntrain_test_split\n\nLinearRegression\n\nأي تدريب موديل\n\nالهدف\nتفهم الداتا بس.\n'
