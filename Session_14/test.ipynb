# %%
import pyodbc

# %%
# This connection string defines how to connect to the SQL Server database
# It specifies the ODBC driver, server name, database name,
# and uses Windows authentication (Trusted Connection)
conn_str = (
    'DRIVER={ODBC Driver 17 for SQL Server};' # Basic
    'SERVER=localhost\\SQLEXPRESS;' # server name
    'DATABASE=Company;' # database name
    'Trusted_Connection=yes;'
)

# %%
# This function creates and returns a connection to the database
# using the connection string (conn_str) and pyodbc library
def get_db_connection() :
    connection = pyodbc.connect(conn_str)
    return connection

# %%
def add_customer (customer) :
    try :
        # 1- Open DB Connection
        conn = get_db_connection()
        # 2- create cursor to run command() on DB
        cursor = conn.cursor()
        # 3- write SQL insert Command
        sql_insert = """
            INSERT INTO dbo.Customers (CustomerID, Name, Age, Gender, Region)
            VALUES (?, ?, ?, ?, ?)
        """
     # 4. Execute the SQL command with the data from "customer" dictionary
        cursor.execute(
            sql_insert,
            #  values in dictionary
            customer['customer_id'],
            customer['name'],
            customer['age'],
            customer['gender'],
            customer['region']
        )

        # 5. Save the changes (phisically) in the database
        conn.commit()

        # Return success message
        return True, "Customer added successfully"
    except Exception as e:
        return False, str(e)
    finally:
        # 6. Always close the connection
        conn.close()

# %%
customer = {'customer_id' : 2227235, 'name' : 'Hassan', 'age' : 41, 'gender' : 'male', 'region' : 'USA'}
success , message = add_customer(customer)
print(success)
print(message)
# Out:
# True
# Customer added successfully

# %%
# ====================================================
# Function to Get All Customers from Database
# ====================================================

def get_customers():
    """
    This function reads ALL customers from the database and returns them as a list of dictionaries.

    Steps it performs:
    1. Connects to the SQL Server database
    2. Executes a SELECT query to get all customer records
    3. Converts each database row into a Python dictionary (object)
    4. Returns a list of customer dictionaries
    """

    try:
        # 1. Open a connection to the database
        # - get_db_connection() opens the "door" to SQL Server
        conn = get_db_connection()

        # 2. Create a cursor
        # - A cursor allows us to run SQL commands on the database
        cursor = conn.cursor()

        # 3. Write and execute the SQL SELECT query
        # - This query retrieves all columns for all customers
        cursor.execute("""
        # بكتب الامر اللي انا عاوز اعمله في ال sql
            SELECT CustomerID, Name, Age, Gender, Region
            FROM dbo.Customers
        """)

        # 4. Fetch all rows returned by the query
        # - rows is a list of records from the database
        rows = cursor.fetchall()

        # 5. Create an empty list to store customer dictionaries
        customers = []

        # 6. Loop through each row and convert it into a Python dictionary
        for row in rows:
            customer = {
                "customer_id": row.CustomerID,  # Get CustomerID column
                "name": row.Name,               # Get Name column
                "age": row.Age,                 # Get Age column
                "gender": row.Gender,           # Get Gender column
                "region": row.Region            # Get Region column
            }
            # Add the dictionary to the list of customers
            customers.append(customer)

        return True, customers

    except Exception as e:
        return False, str(e)

    finally:
        conn.close()

# %%
success, customers = get_customers()
if success:
    print("Customers found:", len(customers))
    for c in customers:
        print(c)
# Out:
# Customers found: 52
# {'customer_id': 1, 'name': 'Ahmed Hassan', 'age': 30, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 2, 'name': 'Mohamed Tarek', 'age': 42, 'gender': 'Male', 'region': 'Alexandria'}
# {'customer_id': 3, 'name': 'Heba Ali', 'age': 28, 'gender': 'Female', 'region': 'Giza'}
# {'customer_id': 4, 'name': 'Salma Nabil', 'age': 35, 'gender': 'Female', 'region': 'Mansoura'}
# {'customer_id': 5, 'name': 'Youssef Adel', 'age': 39, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 6, 'name': 'Nourhan Samir', 'age': 25, 'gender': 'Female', 'region': 'Ismailia'}
# {'customer_id': 7, 'name': 'Ali Mahmoud', 'age': 33, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 8, 'name': 'Mona Adel', 'age': 29, 'gender': 'Female', 'region': 'Giza'}
# {'customer_id': 9, 'name': 'Omar Samy', 'age': 41, 'gender': 'Male', 'region': 'Alexandria'}
# {'customer_id': 10, 'name': 'Dina Hossam', 'age': 26, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 11, 'name': 'Karim Fathy', 'age': 38, 'gender': 'Male', 'region': 'Mansoura'}
# {'customer_id': 12, 'name': 'Rania Saeed', 'age': 34, 'gender': 'Female', 'region': 'Tanta'}
# {'customer_id': 13, 'name': 'Mostafa Adel', 'age': 45, 'gender': 'Male', 'region': 'Asyut'}
# {'customer_id': 14, 'name': 'Sara Emad', 'age': 22, 'gender': 'Female', 'region': 'Ismailia'}
# {'customer_id': 15, 'name': 'Ahmed Samir', 'age': 31, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 16, 'name': 'Noha Salah', 'age': 28, 'gender': 'Female', 'region': 'Alexandria'}
# {'customer_id': 17, 'name': 'Mahmoud Hassan', 'age': 40, 'gender': 'Male', 'region': 'Sohag'}
# {'customer_id': 18, 'name': 'Yara Mohamed', 'age': 24, 'gender': 'Female', 'region': 'Giza'}
# {'customer_id': 19, 'name': 'Islam Nabil', 'age': 36, 'gender': 'Male', 'region': 'Fayoum'}
# {'customer_id': 20, 'name': 'Hanan Ali', 'age': 43, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 21, 'name': 'Khaled Tamer', 'age': 27, 'gender': 'Male', 'region': 'Minia'}
# {'customer_id': 22, 'name': 'Reem Ashraf', 'age': 30, 'gender': 'Female', 'region': 'Alexandria'}
# {'customer_id': 23, 'name': 'Tarek Adel', 'age': 50, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 24, 'name': 'Shimaa Fawzy', 'age': 35, 'gender': 'Female', 'region': 'Zagazig'}
# {'customer_id': 25, 'name': 'Mohsen Gamal', 'age': 39, 'gender': 'Male', 'region': 'Suez'}
# {'customer_id': 26, 'name': 'Farah Hassan', 'age': 21, 'gender': 'Female', 'region': 'Ismailia'}
# {'customer_id': 27, 'name': 'Hossam Reda', 'age': 44, 'gender': 'Male', 'region': 'Luxor'}
# {'customer_id': 28, 'name': 'Nancy Magdy', 'age': 32, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 29, 'name': 'Ayman Youssef', 'age': 37, 'gender': 'Male', 'region': 'Alexandria'}
# {'customer_id': 30, 'name': 'Lamiaa Saber', 'age': 41, 'gender': 'Female', 'region': 'Giza'}
# {'customer_id': 31, 'name': 'Fady Nasser', 'age': 28, 'gender': 'Male', 'region': 'Assiut'}
# {'customer_id': 32, 'name': 'Mai Ehab', 'age': 26, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 33, 'name': 'Sherif Kamal', 'age': 48, 'gender': 'Male', 'region': 'Mansoura'}
# {'customer_id': 34, 'name': 'Esraa Adel', 'age': 23, 'gender': 'Female', 'region': 'Tanta'}
# {'customer_id': 35, 'name': 'Bassem Younes', 'age': 35, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 36, 'name': 'Heba Mahmoud', 'age': 31, 'gender': 'Female', 'region': 'Alexandria'}
# {'customer_id': 37, 'name': 'Wael Ashraf', 'age': 42, 'gender': 'Male', 'region': 'Giza'}
# {'customer_id': 38, 'name': 'Nadine Sameh', 'age': 27, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 39, 'name': 'Adel Hassan', 'age': 55, 'gender': 'Male', 'region': 'Aswan'}
# {'customer_id': 40, 'name': 'Riham Lotfy', 'age': 34, 'gender': 'Female', 'region': 'Fayoum'}
# {'customer_id': 41, 'name': 'Mina Fekry', 'age': 29, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 42, 'name': 'Salma Ashraf', 'age': 22, 'gender': 'Female', 'region': 'Alexandria'}
# {'customer_id': 43, 'name': 'Hany Saad', 'age': 46, 'gender': 'Male', 'region': 'Qena'}
# {'customer_id': 44, 'name': 'Doaa Magdy', 'age': 38, 'gender': 'Female', 'region': 'Mansoura'}
# {'customer_id': 45, 'name': 'Mazen Adel', 'age': 33, 'gender': 'Male', 'region': 'Cairo'}
# {'customer_id': 46, 'name': 'Rasha Hamdy', 'age': 41, 'gender': 'Female', 'region': 'Suez'}
# {'customer_id': 47, 'name': 'Mohamed Khalil', 'age': 36, 'gender': 'Male', 'region': 'Giza'}
# {'customer_id': 48, 'name': 'Nour Adel', 'age': 24, 'gender': 'Female', 'region': 'Cairo'}
# {'customer_id': 49, 'name': 'Sayed Fathy', 'age': 52, 'gender': 'Male', 'region': 'Minia'}
# {'customer_id': 50, 'name': 'Basmalah Ahmed', 'age': 20, 'gender': 'Female', 'region': 'Alexandria'}
# {'customer_id': 2227235, 'name': 'Hassan', 'age': 41, 'gender': 'male', 'region': 'USA'}
# {'customer_id': 2227253, 'name': 'Abdelrahman', 'age': 40, 'gender': 'male', 'region': 'USA'}

# %%
def update_customers()
